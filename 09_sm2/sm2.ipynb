# %% [markdown]
# ## Sequential Algorithm for Open-Pit Mine Scheduling Problem

# %% [markdown]
# ### Installing packages

# %%
# !pip install -q pandas==3.0.2 numpy==2.4.4 mip==1.17.6 gurobipy==13.0.1 matplotlib==3.10.8 plotly==6.6.0

# %% [markdown]
# ### Importing packages

# %%
import time, pandas as pd, gurobipy as gp, plotly.express as px, matplotlib.pyplot as plt, numpy as np
from mip import *

# %% [markdown]
# ### Loading block model file

# %%
# Load block model 
cols = ["id", "x", "y", "z", "tonn", "ore", "waste", "ni", "grade", "process", "blockvalue"]

# Read the block model (space-separated format)
blocks = pd.read_csv("sm2.blocks", sep=r"\s+", header=None, names=cols, engine="python")

# Determine destination based value
blocks["destination"] = (blocks["blockvalue"] > 0).astype(int)

# Add a column to store the extraction period (initially empty)
blocks["period"] = pd.NA

print(f"Loaded {len(blocks):,} blocks")
# Out:
# Loaded 99,014 blocks

# %% [markdown]
# ### Loading block precedences file

# %%
# Load precedence relations (Precedence file format: block_id  n_prec  prec1  prec2  ... )
precedence = {}
with open("sm2.prec") as f:
    for line in f:
        parts = line.strip().split()
        block_id = int(parts[0])
        n_prec = int(parts[1])
        precedence[block_id] = [int(parts[k]) for k in range(2, 2+n_prec)]

print(f"Loaded {sum(len(precs) for precs in precedence.values()):,} precedences")
# Out:
# Loaded 96,642 precedences

# %% [markdown]
# ### Sequential Algorithm for Open-Pit Mine Scheduling

# %% [markdown]
# ### Using the process capacity provided by Gonzalo Muñoz - MineLib CPIT Results

# %%
# Parameters 
max_period = 22     # Maximum number of scheduling periods
MC = 12_000_000     # Maximum Mine Capacity (tons)
PC_default = 2_200_000     # Maximum Process Capacity (tons)
alpha = 0.10        # Discount rate for Net Present Value (NPV)

# Using the process capacity provided by Gonzalo Muñoz
PC_t = {0: 1_449_753, 1: 1_771_706, 2: 2_111_584, 3: 2_223_639, 4: 2_262_883, 5: 2_238_018, 6: 2_230_943, 7: 2_208_736,
    8: 2_252_504, 9: 2_247_817, 10: 2_253_773, 11: 2_317_155, 12: 2_292_171, 13: 2_299_402, 14: 2_302_645, 15: 2_302_233,
    16: 2_354_694, 17: 2_355_062, 18: 1_726_272, 19: 1_083_166, 20: 1_024_603, 21: 518_991}

# Sequential Optimization 
code_start = time.time()
period_profit = []   # Store discounted values per period
extracted = set()    # Keep track of already extracted blocks

# Build a model using Gurobi Solver, if available, or use open-source CBC solver (MIP Package Default)
try:
    Model(sense=MAXIMIZE, solver_name="GRB").clear()
    solver_name = "GRB"
except Exception:
    solver_name = "CBC"
print(f"Using {solver_name} solver")
print("Starting optimization")
 
# Loop over scheduling periods
for t in range(max_period):

    # Available blocks = those not extracted yet
    B = list(blocks.index[~blocks["id"].isin(extracted)])
    if not B:
        break  # Stop if no available blocks remain

    # Extract data for available blocks
    ids = blocks.loc[B, "id"].tolist()
    v = blocks.loc[B, "blockvalue"].tolist()
    w = blocks.loc[B, "tonn"].tolist()
    o = blocks.loc[B, "process"].tolist()

    model = Model(sense=MAXIMIZE, solver_name=solver_name)
    model.max_seconds = 600  # 10 minutes

    # Decision variables: x[b] = 1 if block b is extracted in this period
    x = [model.add_var(var_type=BINARY) for _ in B]

    # Objective: maximize undiscounted profit in this period
    model.objective = xsum(x[b] * v[b] for b in range(len(B)))

    # Precedence constraints: a block can only be extracted if its predecessors are extracted
    id_to_var = {ids[b]: b for b in range(len(B))}
    for bid in ids:
        if bid in precedence:
            for prec in precedence[bid]:
                if prec in extracted:
                    continue  # Already extracted in earlier period
                elif prec in id_to_var:
                    model += x[id_to_var[bid]] <= x[id_to_var[prec]]
                else:
                    # Predecessor not extracted yet → force this block = 0
                    model += x[id_to_var[bid]] == 0

    # Capacity constraint
    model += xsum(o[b] * x[b] for b in range(len(B))) <= PC_t[t]
    model += xsum(w[b] * x[b] for b in range(len(B))) <= MC

    # Solve optimization 
    opt_start = time.time()
    model.optimize()
    opt_time = time.time() - opt_start

    # Check solution status
    if model.status in (OptimizationStatus.OPTIMAL, OptimizationStatus.FEASIBLE) and model.objective_value > 0:
        undiscounted_value = model.objective_value
        discounted_value = undiscounted_value / ((1 + alpha) ** t)
        period_profit.append(discounted_value)

        # Update extracted blocks
        files_start = time.time()
        selected = []
        for b, var in enumerate(x):
            if var.x > 0.5:  # If block is selected
                bid = ids[b]
                extracted.add(bid)
                blocks.loc[blocks["id"] == bid, "period"] = t
                selected.append(bid)
        files_time = time.time() - files_start

        # Print summary for this period
        print(f"Period: {t} | "
              f"Undiscounted: {undiscounted_value:,.0f} | " f"Discounted: {discounted_value:,.0f} | " f"Blocks: {len(selected)} | "
              f"Opt Time (min): {opt_time/60:.2f} | " f"Files Time (min): {files_time/60:.2f}")
    else:
        break

    # Clear model (free memory before next period)
    model.clear()

# Final Results 
npv = sum(period_profit)  # Net Present Value
print(f"\nNPV: {npv:,.0f}")
print(f"Total blocks extracted: {len(extracted)}")
print(f"Code Time: {(time.time()-code_start)/60:.2f} minutes")

# Save solution 
blocks.to_csv("sm2_solution.csv", index=False)
# Out:
# Using GRB solver
# Starting optimization
# Period: 0 | Undiscounted: 251,721,219 | Discounted: 251,721,219 | Blocks: 487 | Opt Time (min): 0.02 | Files Time (min): 0.00
# Period: 1 | Undiscounted: 255,314,221 | Discounted: 232,103,837 | Blocks: 518 | Opt Time (min): 0.01 | Files Time (min): 0.00
# Period: 2 | Undiscounted: 261,090,142 | Discounted: 215,776,977 | Blocks: 759 | Opt Time (min): 0.01 | Files Time (min): 0.00
# Period: 3 | Undiscounted: 232,600,226 | Discounted: 174,755,993 | Blocks: 751 | Opt Time (min): 0.02 | Files Time (min): 0.00
# Period: 4 | Undiscounted: 209,897,604 | Discounted: 143,362,888 | Blocks: 808 | Opt Time (min): 0.01 | Files Time (min): 0.00
# Period: 5 | Undiscounted: 186,456,853 | Discounted: 115,775,036 | Blocks: 805 | Opt Time (min): 0.01 | Files Time (min): 0.00
# Period: 6 | Undiscounted: 168,808,892 | Discounted: 95,288,219 | Blocks: 770 | Opt Time (min): 0.01 | Files Time (min): 0.00
# Period: 7 | Undiscounted: 153,054,043 | Discounted: 78,540,925 | Blocks: 785 | Opt Time (min): 0.01 | Files Time (min): 0.00
# Period: 8 | Undiscounted: 143,945,123 | Discounted: 67,151,462 | Blocks: 772 | Opt Time (min): 0.01 | Files Time (min): 0.00
# Period: 9 | Undiscounted: 131,775,135 | Discounted: 55,885,521 | Blocks: 789 | Opt Time (min): 0.01 | Files Time (min): 0.01
# Period: 10 | Undiscounted: 121,657,596 | Discounted: 46,904,270 | Blocks: 794 | Opt Time (min): 0.01 | Files Time (min): 0.00
# Period: 11 | Undiscounted: 114,065,001 | Discounted: 39,979,087 | Blocks: 839 | Opt Time (min): 0.01 | Files Time (min): 0.00
# Period: 12 | Undiscounted: 101,449,951 | Discounted: 32,325,081 | Blocks: 896 | Opt Time (min): 0.01 | Files Time (min): 0.01
# Period: 13 | Undiscounted: 88,861,319 | Discounted: 25,739,959 | Blocks: 856 | Opt Time (min): 0.01 | Files Time (min): 0.00
# Period: 14 | Undiscounted: 81,131,074 | Discounted: 21,364,348 | Blocks: 922 | Opt Time (min): 0.01 | Files Time (min): 0.01
# Period: 15 | Undiscounted: 72,047,557 | Discounted: 17,247,612 | Blocks: 1017 | Opt Time (min): 0.01 | Files Time (min): 0.00
# Period: 16 | Undiscounted: 60,670,770 | Discounted: 13,203,727 | Blocks: 1173 | Opt Time (min): 0.01 | Files Time (min): 0.01
# Period: 17 | Undiscounted: 43,531,079 | Discounted: 8,612,392 | Blocks: 1163 | Opt Time (min): 0.01 | Files Time (min): 0.01
# Period: 18 | Undiscounted: 29,601,186 | Discounted: 5,324,033 | Blocks: 978 | Opt Time (min): 0.00 | Files Time (min): 0.01
# Period: 19 | Undiscounted: 19,587,226 | Discounted: 3,202,668 | Blocks: 799 | Opt Time (min): 0.01 | Files Time (min): 0.00
# Period: 20 | Undiscounted: 12,630,925 | Discounted: 1,877,507 | Blocks: 948 | Opt Time (min): 0.00 | Files Time (min): 0.00
# Period: 21 | Undiscounted: 3,153,401 | Discounted: 426,121 | Blocks: 435 | Opt Time (min): 0.00 | Files Time (min): 0.00
#
# NPV: 1,646,568,880
# Total blocks extracted: 18064
# Code Time: 0.90 minutes

# %% [markdown]
# ### Mine Scheduling 3D Plot

# %%
# Block dimensions
dx, dy, dz = 50, 50, 1
# Filter extracted blocks and prepare data
d = blocks.loc[blocks.period.notna()].copy()
d["period"] = d["period"].astype(int)
d[["x","y","z"]] *= [dx, dy, dz]
d["period"] -= d["period"].min()
d["period"] = d["period"].astype(str)
# Axis scaling for correct proportions
r = d[["x","y","z"]].max() - d[["x","y","z"]].min()
s = r.max()
# 3D categorical scatter with Plotly default colors
fig = px.scatter_3d(d, x="x", y="y", z="z", color="period", color_discrete_sequence=px.colors.qualitative.Plotly,
    category_orders={"period": sorted(d["period"], key=int)}, labels={"color": "Periods"}, 
    title="Mine Scheduling", width=900, height=500).update_traces(marker=dict(symbol="square", size=7, 
    line=dict(width=0.5, color="black"))).update_layout(scene=dict(xaxis_title="X (m)", yaxis_title="Y (m)", 
    zaxis_title="Elevation (m)", aspectmode="manual", aspectratio=dict(x=r.x/s, y=r.y/s, z=r.z/s)))
fig.show()

# %%
# Salve 3D Plot 
fig.write_html("sm2_plot.html", full_html=True, include_plotlyjs="cdn",
    config={"responsive": True}, default_width="100vw", default_height="100vh")

# %% [markdown]
# ### Capacity & Grade Chart

# %%
# Consider only extracted blocks
df = blocks.dropna(subset=["period"]).copy()

# Processed material only (destination == 1)
df["w_proc"]  = df["process"]                      # processed tonnage
df["g_proc"] = df["ni"] * df["w_proc"]             # contained metal

# Aggregate by period
summary = (df.groupby("period", as_index=False).agg(ton_mine=("tonn", "sum"), ton_plant=("w_proc", "sum"), metal=("g_proc", "sum")))

# Weighted average feed grade
summary["grade_avg"] = summary["metal"] / summary["ton_plant"]
summary["grade_avg"] = summary["grade_avg"].fillna(0)

# Plot
x = np.arange(len(summary))
w = 0.35
fig, ax1 = plt.subplots(figsize=(8, 4))

# Bars: Mine vs Process capacity (Mt)
ax1.bar(x - w/2, summary["ton_mine"] / 1e6, w, label="Mine (Mt)", color="#FFC44D", edgecolor="black")
ax1.bar(x + w/2, summary["ton_plant"] / 1e6, w, label="Process (Mt)", color="#4C5BFF", edgecolor="black")

ax1.set_xlabel("Period")
ax1.set_ylabel("Capacity (Mt)")
ax1.set_xticks(x)
ax1.set_xticklabels(summary["period"].astype(int))

# Y-axis from zero to slightly above max
ax1.set_ylim(0, 1.1 * max(summary["ton_mine"].max(), summary["ton_plant"].max()) / 1e6)

# Secondary axis: Feed grade
ax2 = ax1.twinx()
ax2.plot(x, summary["grade_avg"], color="green", linewidth=2.5, label="Ni (%)")

ax2.set_ylabel("Ni (%)")
ax2.set_ylim(0, 1.15 * summary["grade_avg"].max())

# Visual hierarchy
ax1.patch.set_visible(False)

# Legend
fig.legend(loc="upper center", ncol=3, bbox_to_anchor=(0.5, 1.08), frameon=False)

plt.tight_layout()
plt.show()

# %%
# Salve plot
fig.savefig("sm2_results.png", dpi=300, bbox_inches="tight", facecolor="white")
plt.show()
